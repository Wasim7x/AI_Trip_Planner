# %%
print("kskf")
# Out:
# kskf

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm=ChatGroq(model="llama-3.3-70b-versatile")

# %%
llm.invoke("hi")
# Out:
# AIMessage(content="It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 36, 'total_tokens': 59, 'completion_time': 0.050522289, 'prompt_time': 0.003198995, 'queue_time': 0.058909235, 'total_time': 0.053721284}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--eac01c3a-cffb-4f9a-af86-d218655991b2-0', usage_metadata={'input_tokens': 36, 'output_tokens': 23, 'total_tokens': 59})

# %%
@tool
def add(a: int, b: int) -> int:
    return a + b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 @tool
#       2 def add(a: int, b: int) -> int:
#       3     return a + b
#
# NameError: name 'tool' is not defined

# %%
from langchain_groq import ChatGroq

# %%
model_name = "deepseek-r1-distill-llama-70b"
groq_api_key = "groq_api_key"

# %%
llm=ChatGroq(model=model_name, api_key=groq_api_key)

# %%
llm.invoke("hi")
# Out:
# AIMessage(content='<think>\n\n</think>\n\nHello! How can I assist you today? 😊', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 4, 'total_tokens': 20, 'completion_time': 0.079928086, 'prompt_time': 0.009445877, 'queue_time': 0.107250193, 'total_time': 0.089373963}, 'model_name': 'deepseek-r1-distill-llama-70b', 'system_fingerprint': 'fp_1bbe7845ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--28d3a49f-deb2-48da-bb37-7e1466ac058f-0', usage_metadata={'input_tokens': 4, 'output_tokens': 16, 'total_tokens': 20})
